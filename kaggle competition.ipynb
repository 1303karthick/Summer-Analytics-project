# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#reading the training data

# %%
df=pd.read_csv('C:/Users/KARTHICK/Desktop/train.csv')

# %%
df.head()
# Out:
#    Id  Age  Attrition BusinessTravel              Department  \
# 0   1   30          0     Non-Travel  Research & Development
# 1   2   36          0  Travel_Rarely  Research & Development
# 2   3   55          1  Travel_Rarely                   Sales
# 3   4   39          0  Travel_Rarely  Research & Development
# 4   5   37          0  Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 2          3        Medical             571
# 1                12          4  Life Sciences            1614
# 2                 2          1        Medical             842
# 3                24          1  Life Sciences            2014
# 4                 3          3          Other             689
#
#    EnvironmentSatisfaction  ... PerformanceRating  StockOptionLevel  \
# 0                        3  ...                 3                 0
# 1                        3  ...                 3                 2
# ...

# %%
df.shape
# Out:
# (1628, 29)

# %%
data=df

# %%
#preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
data.select_dtypes(include='object')
data=data.apply(lb.fit_transform)

# %%
data
# Out:
#         Id  Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0        0   12          0               0           1                 1
# 1        1   18          0               2           1                11
# 2        2   37          1               2           2                 1
# 3        3   21          0               2           1                23
# 4        4   19          0               2           1                 2
# ...    ...  ...        ...             ...         ...               ...
# 1623  1623   24          1               1           1                18
# 1624  1624   37          1               2           2                 1
# 1625  1625    7          1               2           2                 8
# 1626  1626   11          1               2           0                12
# 1627  1627   11          1               2           1                17
#
#       Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  ...  \
# ...

# %%
for i in data.columns:
    print(i ,data[i].nunique())
# Out:
# Id 1628
# Age 43
# Attrition 2
# BusinessTravel 3
# Department 3
# DistanceFromHome 29
# Education 5
# EducationField 6
# EmployeeNumber 1000
# EnvironmentSatisfaction 4
# Gender 2
# JobInvolvement 4
# JobRole 9
# JobSatisfaction 4
# MaritalStatus 3
# MonthlyIncome 941
# NumCompaniesWorked 10
# OverTime 2
# PercentSalaryHike 15
# PerformanceRating 2
# StockOptionLevel 4
# TotalWorkingYears 39
# TrainingTimesLastYear 7
# YearsAtCompany 36
# YearsInCurrentRole 19
# YearsSinceLastPromotion 16
# YearsWithCurrManager 18
# CommunicationSkill 5
# Behaviour 1

# %%
data.shape==data.dropna().shape
# Out:
# True

# %%
data.drop('Id',inplace=True,axis=1)

# %%
#feature scaling

# %%
df_fs = df[['Age',
                           'MonthlyIncome', 'OverTime',
                           'EmployeeNumber',
                          'DistanceFromHome', 'YearsAtCompany',
                           'TotalWorkingYears', 
                            'NumCompaniesWorked',
                           'JobInvolvement', 'PercentSalaryHike',
                           'StockOptionLevel', 
                           'YearsWithCurrManager',
                           'EnvironmentSatisfaction',
                           'EducationField', 'Attrition']]

# %%
df_fs
# Out:
#       Age  MonthlyIncome OverTime  EmployeeNumber  DistanceFromHome  \
# 0      30           2564       No             571                 2
# 1      36           4663      Yes            1614                12
# 2      55           5160       No             842                 2
# 3      39           4108       No            2014                24
# 4      37           9434       No             689                 3
# ...   ...            ...      ...             ...               ...
# 1623   42           2759      Yes             752                19
# 1624   55           5160       No             842                 2
# 1625   25           4400       No            1439                 9
# 1626   29           2335      Yes            1844                13
# 1627   29           2389      Yes             315                18
#
#       YearsAtCompany  TotalWorkingYears  NumCompaniesWorked  JobInvolvement  \
# ...

# %%
#preprocessing for the selected fields

# %%
df_fs.apply(lb.fit_transform)
# Out:
#       Age  MonthlyIncome  OverTime  EmployeeNumber  DistanceFromHome  \
# 0      12            152         0             288                 1
# 1      18            432         1             778                11
# 2      37            495         0             423                 1
# 3      21            361         0             971                23
# 4      19            723         0             352                 2
# ...   ...            ...       ...             ...               ...
# 1623   24            194         1             385                18
# 1624   37            495         0             423                 1
# 1625    7            399         0             696                 8
# 1626   11            102         1             890                12
# 1627   11            119         1             159                17
#
#       YearsAtCompany  TotalWorkingYears  NumCompaniesWorked  JobInvolvement  \
# ...

# %%
df_fs.drop('EmployeeNumber',inplace=True,axis=1)
# Out:
# C:\Users\KARTHICK\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_fs['EducationField'] = lb.fit_transform(df_fs['EducationField'])
df_fs['OverTime'] = lb.fit_transform(df_fs['OverTime'])

df_fs
# Out:
# C:\Users\KARTHICK\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\KARTHICK\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#       Age  MonthlyIncome  OverTime  DistanceFromHome  YearsAtCompany  \
# 0      30           2564         0                 2              11
# ...

# %%
#reading test data

# %%
dft=pd.read_csv('C:/Users/KARTHICK/Desktop/test.csv')

# %%
data1=dft

# %%
# preprocessing testing data

# %%
data1.select_dtypes(include='object')
data1=data1.apply(lb.fit_transform)

# %%
#selecting important features

# %%
dftest = data1[['Age',
                           'MonthlyIncome', 'OverTime',
                           'EmployeeNumber',
                          'DistanceFromHome', 'YearsAtCompany',
                           'TotalWorkingYears', 
                            'NumCompaniesWorked',
                           'JobInvolvement', 'PercentSalaryHike',
                           'StockOptionLevel', 
                           'YearsWithCurrManager',
                           'EnvironmentSatisfaction',
                           'EducationField']]
# Out:
#      Age  MonthlyIncome  OverTime  EmployeeNumber  DistanceFromHome  \
# 0     10             21         0              88                 8
# 1     13            254         0             149                 5
# 2     19            278         1             115                 5
# 3     24            281         1             181                 0
# 4     27            187         0             213                 3
# ..   ...            ...       ...             ...               ...
# 465   14              4         0             386                 1
# 466    0              9         1             370                 2
# 467    6             89         1             146                22
# 468   13            261         0              85                22
# 469   18            339         0             374                 4
#
#      YearsAtCompany  TotalWorkingYears  NumCompaniesWorked  JobInvolvement  \
# ...

# %%
dftest.drop('EmployeeNumber',inplace=True,axis=1)
# Out:
# C:\Users\KARTHICK\anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
dftest
# Out:
#      Age  MonthlyIncome  OverTime  DistanceFromHome  YearsAtCompany  \
# 0     10             21         0                 8               5
# 1     13            254         0                 5               7
# 2     19            278         1                 5               7
# 3     24            281         1                 0               4
# 4     27            187         0                 3               9
# ..   ...            ...       ...               ...             ...
# 465   14              4         0                 1               1
# 466    0              9         1                 2               0
# 467    6             89         1                22               6
# 468   13            261         0                22               9
# 469   18            339         0                 4               3
#
#      TotalWorkingYears  NumCompaniesWorked  JobInvolvement  PercentSalaryHike  \
# ...

# %%
xtest=dftest

# %%
xtrain=df_fs.drop('Attrition',axis=1)

# %%
ytrain=df_fs['Attrition']

# %%
xtrain
# Out:
#       Age  MonthlyIncome  OverTime  DistanceFromHome  YearsAtCompany  \
# 0      30           2564         0                 2              11
# 1      36           4663         1                12               3
# 2      55           5160         0                 2               9
# 3      39           4108         0                24               7
# 4      37           9434         0                 3              10
# ...   ...            ...       ...               ...             ...
# 1623   42           2759         1                19               2
# 1624   55           5160         0                 2               9
# 1625   25           4400         0                 9               3
# 1626   29           2335         1                13               2
# 1627   29           2389         1                18               4
#
#       TotalWorkingYears  NumCompaniesWorked  JobInvolvement  \
# 0                    12                   0               3
# ...

# %%
ytrain
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1623    1
# 1624    1
# 1625    1
# 1626    1
# 1627    1
# Name: Attrition, Length: 1628, dtype: int64

# %%
#model selection

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR=LogisticRegression(solver='saga',max_iter=100000,C=10,penalty='l2')

# %%
# training the model

# %%
LR.fit(xtrain,ytrain)
# Out:
# LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='saga', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
t1=LR.predict_proba(xtest)

# %%
t2=t1[:,1]

# %%
sample_s=pd.read_csv('C:/Users/KARTHICK/Desktop/ss1.csv')

# %%
sample_s.drop('Attrition',axis=1)
sample_s['Attrition']=t2
sample_s.to_csv('submission_pred211.csv',index=False)
